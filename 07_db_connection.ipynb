# %%
# !pip install sqlalchemy psycopg2-binary
# !pip freeze > requirements.txt
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.54-cp314-cp314-win_amd64.whl.metadata (9.9 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.13-cp314-cp314-win_amd64.whl.metadata (5.1 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.5.6-cp314-cp314-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\.venv\Lib\site-packages (from sqlalchemy) (4.16.0)
# Downloading sqlalchemy-2.0.54-cp314-cp314-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.2 MB 1.3 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.2 MB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 1.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.1 MB/s  0:00:01
# Downloading psycopg2_binary-2.9.13-cp314-cp314-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 882.9 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/2.9 MB 833.1 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.8/2.9 MB 833.1 kB/s eta 0:00:03
#    -------------- ------------------------- 1.0/2.9 MB 864.4 kB/s eta 0:00:03
#    ------------------ --------------------- 1.3/2.9 MB 887.8 kB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.9 MB 887.8 kB/s eta 0:00:02
#    --------------------- ------------------ 1.6/2.9 MB 885.7 kB/s eta 0:00:02
#    ----------------------------- ---------- 2.1/2.9 MB 986.5 kB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 1.1 MB/s  0:00:02
# Downloading greenlet-3.5.6-cp314-cp314-win_amd64.whl (327 kB)
# Installing collected packages: psycopg2-binary, greenlet, sqlalchemy
#
#    ---------------------------------------- 0/3 [psycopg2-binary]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    ---------------------------------------- 3/3 [sqlalchemy]
#
# Successfully installed greenlet-3.5.6 psycopg2-binary-2.9.13 sqlalchemy-2.0.54

# %%
from sqlalchemy import create_engine, text

engine = create_engine("postgresql://postgres:postgres@localhost:5432/flood_ews")

with engine.connect() as conn:
    result = conn.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema='public';"))
    print(result.fetchall())
# Out:
# [('geography_columns',), ('geometry_columns',), ('spatial_ref_sys',), ('wards',), ('rainfall_daily',), ('dam_discharge_events',)]
