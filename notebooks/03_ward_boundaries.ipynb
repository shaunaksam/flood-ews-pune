# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

wards = gpd.read_file("../data/raw/pune_wards.geojson")
print(wards.shape)
print(wards.columns)
print(wards.head())
print(wards.crs)
print(wards.total_bounds)
# Out:
# (58, 8)
# Index(['tessellate', 'extrude', 'visibility', 'wardnum', 'origin', 'Name1',
#        'Name2', 'geometry'],
#       dtype='str')
#    tessellate  extrude  visibility  wardnum  \
# 0          -1        0          -1        1
# 1          -1        0          -1        2
# 2          -1        0          -1        3
# 3          -1        0          -1        4
# 4          -1        0          -1        5
#
#                                               origin  \
# 0  http://www.pmc.gov.in/sites/default/files/fina...
# 1  http://www.pmc.gov.in/sites/default/files/fina...
# 2  http://www.pmc.gov.in/sites/default/files/fina...
# 3  http://www.pmc.gov.in/sites/default/files/fina...
# 4  http://www.pmc.gov.in/sites/default/files/fina...
#
#                              Name1                         Name2  \
# 0        01 Dhanori - Vishrantwadi        Dhanori - Vishrantwadi
# 1     02 Tingrenagar - Sanjay Park     Tingrenagar - Sanjay Park
# ...

# %%
wards.plot(figsize=(8, 8))
# Out:
# <Axes: >

# %%
from shapely.geometry import Point

test_point = Point(73.8474, 18.5306)   # Point(longitude, latitude)

# %%
match = wards[wards.contains(test_point)]
print(match)
# Out:
#    tessellate  extrude  visibility  wardnum  \
# 9          -1        0          -1       10
#
#                                               origin  \
# 9  http://www.pmc.gov.in/sites/default/files/fina...
#
#                                   Name1                              Name2  \
# 9  10 Shivajinagar Gaothan - Sangamwadi  Shivajinagar Gaothan - Sangamwadi
#
#                                             geometry
# 9  POLYGON ((73.87811 18.54829, 73.87823 18.54868...
