# %%
import pandas as pd

df1 = pd.read_csv("../data/raw/datagov_districtw_jun21_sep25.csv")
df2 = pd.read_csv("../data/raw/opencity_pune_temp_rainfall_1980_2019.csv")

print(df1.shape)
print(df1.head())
print(df2.shape)
print(df2.head())
# Out:
# (6, 75)
#   S.No - June - 2021 District - June-2021  \
# 0                  1                 Pune
# 1                  2              Solapur
# 2                  3               Satara
# 3                  4               Sangli
# 4                  5             Kolhapur
#
#    District Normal RainFall  -June-2021  Total Rainfall - June-2021  \
# 0                                 176.2                       186.4
# 1                                 102.5                       139.6
# 2                                 194.1                       264.6
# 3                                 129.0                       202.7
# 4                                 362.9                       400.6
#
#    % Rainfall - June-2021  Rainy Days - June-2021  \
# 0                   105.8                      15
# 1                   136.2                      14
# 2                   136.3                      17
# 3                   157.1                      14
# ...
